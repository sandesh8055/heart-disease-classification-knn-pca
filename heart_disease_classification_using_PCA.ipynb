# %% [markdown]
# <a href="https://colab.research.google.com/github/sandesh8055/heart-disease-classification-knn-pca/blob/main/heart_disease_classification_using_PCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("/content/heart_dataset.csv")

# %%
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
x=data.drop(['target'],axis=1)
y=data['target']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
predictions=knn.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm=confusion_matrix(y_test,predictions)
ac=accuracy_score(y_test,predictions)

# %%
print(cm)
# Out:
# [[16 12]
#  [15 18]]

# %%
print(ac)
# Out:
# 0.5573770491803278

# %% [markdown]
# PCA

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA(n_components=12)
x_reduced_train=pd.DataFrame(pca.fit_transform(x_train))
x_reduced_test=pd.DataFrame(pca.fit_transform(x_test))

# %%
x_train.shape
# Out:
# (242, 13)

# %%
x_reduced_train.shape
# Out:
# (242, 12)

# %%
x_test.shape
# Out:
# (61, 13)

# %%
x_reduced_test.shape
# Out:
# (61, 12)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=7)

# %%
knn.fit(x_reduced_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
new_predictions=knn.predict(x_reduced_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm=confusion_matrix(y_test,new_predictions)
ac=accuracy_score(y_test,new_predictions)

# %%
print(cm)
# Out:
# [[14 14]
#  [15 18]]

# %%
print(ac)
# Out:
# 0.5245901639344263
